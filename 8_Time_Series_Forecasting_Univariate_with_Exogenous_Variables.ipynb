# %% [markdown]
# <a href="https://colab.research.google.com/github/ChirudeepG/Assignment2/blob/main/8_Time_Series_Forecasting_Univariate_with_Exogenous_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret-ts-alpha
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 468 kB 24.6 MB/s
# ...
#      |████████████████████████████████| 79.9 MB 124 kB/s
# ...
#      |████████████████████████████████| 69 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 42.3 MB/s
# ...
#      |████████████████████████████████| 303 kB 72.6 MB/s
# ...
#      |████████████████████████████████| 24.8 MB 2.0 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 38.9 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 52.5 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 45.0 MB/s
# ...
#      |████████████████████████████████| 282 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 199 kB 51.9 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 43.7 MB/s
# ...
#      |████████████████████████████████| 199 kB 73.6 MB/s
# ...

# %%
import pandas as pd
from pycaret.datasets import get_data
data = get_data('pycaret_downloads')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True, drop=True)
data = data.asfreq('D')
# Out:
# INFO:logs:Preparing display monitor
#         Date  Total
# 0   7/8/2021   3773
# 1   7/9/2021   3172
# 2  7/10/2021   2079
# 3  7/11/2021   2725
# 4  7/12/2021   4542

# %%
from pycaret.time_series import *
setup(data, fh = 7, fold = 5, session_id = 123)
# Out:
# INFO:logs:PyCaret TSForecastingExperiment
# INFO:logs:Logging name: ts-default-name
# INFO:logs:ML Usecase: MLUsecase.TIME_SERIES
# INFO:logs:version 3.0.0
# INFO:logs:Initializing setup()
# INFO:logs:self.USI: 350d
# ...

# %%
check_stats()
# Out:
#             Test   Test Name    Data             Property  \
# 0        Summary  Statistics  Actual               Length
# 1        Summary  Statistics  Actual                 Mean
# 2        Summary  Statistics  Actual               Median
# 3        Summary  Statistics  Actual   Standard Deviation
# 4        Summary  Statistics  Actual             Variance
# 5        Summary  Statistics  Actual             Kurtosis
# 6        Summary  Statistics  Actual             Skewness
# 7        Summary  Statistics  Actual    # Distinct Values
# 8    White Noise   Ljung-Box  Actual       Test Statictic
# 9    White Noise   Ljung-Box  Actual       Test Statictic
# 10   White Noise   Ljung-Box  Actual              p-value
# 11   White Noise   Ljung-Box  Actual              p-value
# 12   White Noise   Ljung-Box  Actual          White Noise
# 13   White Noise   Ljung-Box  Actual          White Noise
# 14  Stationarity         ADF  Actual         Stationarity
# ...

# %%
plot_model(plot = 'ts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
best=compare_models()
# Out:
#                                                              Model        MAE  \
# arima                                                        ARIMA   592.3089
# auto_arima                                              Auto ARIMA   568.3721
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending   601.9708
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending   629.6515
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...   622.9227
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending   637.0989
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending   641.7692
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending   646.9655
# snaive                                   Seasonal Naive Forecaster   678.7429
# theta                                             Theta Forecaster   640.3909
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...     654.29
# ...

# %%
plot_model(best, plot = 'forecast')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'diagnostics')
# Out:
# WARNING:logs:predict_model >> Prediction Indices do not match test indices. Metrics will not be displayed.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-11b8cbdfd955> in <module>
# ----> 1 predict_model(est, fh = 10)
#
# NameError: name 'est' is not defined
